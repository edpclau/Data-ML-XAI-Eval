# %% [markdown]
# # Model Training with Simulated Datasets

# %% [markdown]
# ## 1. Load Required Libraries and Scripts

# %%
# Import required libraries

#Datawrangling
import pandas as pd
import os

#Models and Hyperparamters (provided as a .py file)
from ParameterOptimization import search_space, models

#Hyperparameter Optiization Algorithm
from skopt import BayesSearchCV

#Train test split
from sklearn.model_selection import train_test_split

#Metrics
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix

#Model Export
import joblib

#Track for loops
from fastprogress.fastprogress import progress_bar

# %% [markdown]
# ## 2. Import Data

# %%
# Simulated Datasets
dir_path = '/Users/eddie/Library/CloudStorage/OneDrive-UniversityofPittsburgh/Research/Projects/Explainability Method Comparison/Data-ML-XAI-Eval/Synthetic Data/Data Files'
# list to store files name
res = []
for (dir_path, dir_names, file_names) in os.walk(dir_path):
    res.extend(file_names)
    
for file in res:
    if file not in ['GroundTruth.csv', '.Rhistory', '.DS_Store']:
        data_path = f'/Users/eddie/Library/CloudStorage/OneDrive-UniversityofPittsburgh/Research/Projects/Explainability Method Comparison/Data-ML-XAI-Eval/Synthetic Data/Data Files/{file}'
        df = pd.read_csv(data_path)
        #Class Imbalance
        print(f"Positive percentage in {file}:", df.Target.mean())

res_ = []
for file in res:
     if file not in ['GroundTruth.csv', '.Rhistory', '.DS_Store']:
        res_.append(file)
# Out:
# Positive percentage in 0_vars_corr_0HC_n25000.csv: 0.50592
# Positive percentage in 0_vars_corr_0HC_n10000_skew_0.5194.csv: 0.5194
# Positive percentage in 0_vars_corr_0HC_n100.csv: 0.43
# Positive percentage in 0_vars_corr_0HC_n10000_skew_0.7354.csv: 0.7354
# Positive percentage in 3_vars_corr_1HC_n10000.csv: 0.4927
# Positive percentage in 0_vars_corr_0HC_n10000_skew_0.8612.csv: 0.8612
# Positive percentage in 0_vars_corr_0HC_n15000.csv: 0.49533333333333335
# Positive percentage in 2_vars_corr_1HC_n10000.csv: 0.5007
# Positive percentage in 0_vars_corr_0HC_n10000_skew_0.9694.csv: 0.9694
# Positive percentage in 0_vars_corr_0HC_n10000_skew_0.9699.csv: 0.9699
# Positive percentage in 0_vars_corr_0HC_n10000_skew_0.7298.csv: 0.7298
# Positive percentage in 0_vars_corr_0HC_n10000_skew_0.6145.csv: 0.6145
# Positive percentage in 2_vars_corr_2HC_n10000.csv: 0.4963
# Positive percentage in 0_vars_corr_0HC_n10000.csv: 0.5098
# Positive percentage in 0_vars_corr_0HC_n10000_skew_0.8608.csv: 0.8608
# Positive percentage in 0_vars_corr_0HC_n5000.csv: 0.503
# Positive percentage in 0_vars_corr_0HC_n10000_skew_0.508.csv: 0.508
# Positive percentage in 0_vars_corr_0HC_n10000_skew_0.6222.csv: 0.6222
# Positive percentage in 3_vars_corr_2HC_n10000B.csv: 0.4963
# Positive percentage in 0_vars_corr_0HC_n1000.csv: 0.526
# Positive percentage in 0_vars_corr_0HC_n30000.csv: 0.49853333333333333
# Positive percentage in 3_vars_corr_2HC_n10000.csv: 0.4979
# Positive percentage in 0_vars_corr_0HC_n20000.csv: 0.5087

# %%
#Train Test Split
data = {}
for file in res_:
        data_path = f'/Users/eddie/Library/CloudStorage/OneDrive-UniversityofPittsburgh/Research/Projects/Explainability Method Comparison/Data-ML-XAI-Eval/Synthetic Data/Data Files/{file}'
        df = pd.read_csv(data_path)
        train, test = train_test_split(df, test_size=0.25, random_state=42)
        data[file] = {
            'X_train': train.drop('Target', axis=1),
            'y_train': train.Target,
            'X_test': test.drop('Target', axis=1),
            'y_test': test.Target
        }
        ##Class Imbalance
        # print(f"Positive percentage in {file} Train:", data[file]['y_train'].mean())
        # print(f"Positive percentage in {file} Test:",  data[file]['y_test'].mean())

# %% [markdown]
# ## 3. Model Training

# %% [markdown]
# ### 3.1 Optimization Parameters

# %%
def accu(estimator, X, y):
    y_pred = estimator.predict(X)
    return accuracy_score(y, y_pred)


def Optimizer(model=None, X_train=None, y_train=None, 
    search_space=None, threshold = None, n_iter = 50, n_jobs = 20, cv = 10):
        """
        Optimize a model using a bayesian search
        """
        search = BayesSearchCV(model, search_space, n_iter=n_iter, n_jobs=n_jobs, cv=cv, scoring = accu, random_state=42, return_train_score = True)

        return search.fit(X_train, y_train)

# %% [markdown]
# ### 3.2 Model Training and Hyperparameter Search

# %%
def training_function(file):
    keys = progress_bar(models.keys())
    trained_models = {}
    for key in keys:
        model = Optimizer(models[key], data[file]['X_train'], data[file]['y_train'], search_space[key], n_iter=10, cv = 10)
        trained_models[key] = model
        filepath = f'/Users/eddie/Library/CloudStorage/OneDrive-UniversityofPittsburgh/Research/Projects/Explainability Method Comparison/Data-ML-XAI-Eval/Model Training/Models/{file}_{key}.joblib'
        joblib.dump(model.best_estimator_, filepath, compress=3) 
    return trained_models

# %%
results = []
for file in res_:
    results.append(training_function(file))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='11' class='' max='11' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [11/11 01:29<00:00]
#     </div>
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# ...
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/eddie/miniconda3/envs/python_env/lib/python3.8/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):

# %% [markdown]
# ## 4. Model Evaluation

# %% [markdown]
# ### 4.1 Evaluation of Models Trained for each Dataset

# %%
data.keys()
# Out:
# dict_keys(['0_vars_corr_0HC_n25000.csv', '0_vars_corr_0HC_n100.csv', '0_vars_corr_0HC_n10000_skew_0.7354.csv', '3_vars_corr_1HC_n10000.csv', '0_vars_corr_0HC_n10000_skew_0.8612.csv', '0_vars_corr_0HC_n15000.csv', '2_vars_corr_1HC_n10000.csv', '0_vars_corr_0HC_n10000_skew_0.9694.csv', '2_vars_corr_2HC_n10000.csv', '0_vars_corr_0HC_n10000.csv', '0_vars_corr_0HC_n5000.csv', '0_vars_corr_0HC_n10000_skew_0.508.csv', '0_vars_corr_0HC_n10000_skew_0.6222.csv', '3_vars_corr_2HC_n10000B.csv', '0_vars_corr_0HC_n1000.csv', '3_vars_corr_2HC_n10000.csv', '0_vars_corr_0HC_n20000.csv'])

# %%
for i in range(len(res_)):
    for model in models:
        pd.DataFrame(imb_results[i][model].cv_results_).to_csv(f'/Users/eddie/Library/CloudStorage/OneDrive-UniversityofPittsburgh/Research/XAI method performacne when Explainaing the PORT Dataset/Results/Models/Model Evals/Simulated/{res_[i]}_{model}_optim.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/eddie/Library/CloudStorage/OneDrive-UniversityofPittsburgh/Research/XAI method performacne when Explainaing the PORT Dataset/Code/Model Training Simulated Data.ipynb Cell 16 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/Users/eddie/Library/CloudStorage/OneDrive-UniversityofPittsburgh/Research/XAI%20method%20performacne%20when%20Explainaing%20the%20PORT%20Dataset/Code/Model%20Training%20Simulated%20Data.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> for i in range(len(res_)):
#       <a href='vscode-notebook-cell:/Users/eddie/Library/CloudStorage/OneDrive-UniversityofPittsburgh/Research/XAI%20method%20performacne%20when%20Explainaing%20the%20PORT%20Dataset/Code/Model%20Training%20Simulated%20Data.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a>     for model in models:
# ----> <a href='vscode-notebook-cell:/Users/eddie/Library/CloudStorage/OneDrive-UniversityofPittsburgh/Research/XAI%20method%20performacne%20when%20Explainaing%20the%20PORT%20Dataset/Code/Model%20Training%20Simulated%20Data.ipynb#X21sZmlsZQ%3D%3D?line=2'>3</a>         pd.DataFrame(imb_results[i][model].cv_results_).to_csv(f'/Users/eddie/Library/CloudStorage/OneDrive-UniversityofPittsburgh/Research/XAI method performacne when Explainaing the PORT Dataset/Results/Models/Model Evals/Simulated/{res_[i]}_{model}_optim.csv')
#
# NameError: name 'imb_results' is not defined

# %%
for i in range(len(res_)):
    evals = pd.DataFrame(columns=['Accu','Precision','Recall','F1','TNR', 'TPR','TP','FP','TN','FN'],
                    index=models.keys())
    for key in models.keys():
        y_pred = imb_results[i][key].best_estimator_.predict(data[res_[i]]['X_test'])
        accu = accuracy_score(data[res_[i]]['y_test'], y_pred)
        (prec, rec, f, _) = precision_recall_fscore_support(data[res_[i]]['y_test'], y_pred, average='binary')
        (tn, fp, fn, tp) = confusion_matrix(data[res_[i]]['y_test'], y_pred).ravel()
        tpr = tp/(tp+fn)
        tnr = tn/(tn+fp)
        
        evals.loc[key] = accu, prec, rec, f, tnr, tpr, tp, fp, tn, fn
    evals.to_csv(f'/Users/eddie/Library/CloudStorage/OneDrive-UniversityofPittsburgh/Research/XAI method performacne when Explainaing the PORT Dataset/Results/Models/Model Evals/{res_[i]}_model_evals_optim.csv')
    print(evals)


for i in range(len(res_)):
    evals = pd.DataFrame(columns=['Accu','Precision','Recall','F1','TNR', 'TPR','TP','FP','TN','FN'],
                    index=models.keys())
    for key in models.keys():
        y_pred = imb_results_non_optim[i][key].predict(data[res_[i]]['X_test'])
        accu = accuracy_score(data[res_[i]]['y_test'], y_pred)
        (prec, rec, f, _) = precision_recall_fscore_support(data[res_[i]]['y_test'], y_pred, average='binary')
        (tn, fp, fn, tp) = confusion_matrix(data[res_[i]]['y_test'], y_pred).ravel()
        tpr = tp/(tp+fn)
        tnr = tn/(tn+fp)
        
        evals.loc[key] = accu, prec, rec, f, tnr, tpr, tp, fp, tn, fn
    evals.to_csv(f'/Users/eddie/Library/CloudStorage/OneDrive-UniversityofPittsburgh/Research/XAI method performacne when Explainaing the PORT Dataset/Results/Models/Model Evals/{res_[i]}_model_evals.csv')
    print(evals)

# %%
from imp import reload
import itertools
from unittest import result
import shap
import ROAR
reload(ROAR)


from multiprocess.pool import Pool 


# def reps(i,k):
#     return ROAR.single_roar(data[res_[1]]['X_train'], data[res_[1]]['y_train'], data[res_[1]]['X_test'], data[res_[1]]['y_test'], imb_results_non_optim[1]['RandomForest'], explainer = shap.explainers.Tree, t = 1, shap_values = None)



def reps(i,k):
    return f'{i} : {k}'

results = pool.starmap(reps, )



models = ['PassiveAgressive','SGDClassifier','RandomForest','Perceptron','RidgeClassifier','LogisticRegression','DecisionTree','XGBoost','MultinomialNB', 'GaussianNB']

  
results
# Out:
# ['0_vars_corr_0HC_n25000.csv : PassiveAgressive',
#  '0_vars_corr_0HC_n25000.csv : SGDClassifier',
#  '0_vars_corr_0HC_n25000.csv : RandomForest',
#  '0_vars_corr_0HC_n25000.csv : Perceptron',
#  '0_vars_corr_0HC_n25000.csv : RidgeClassifier',
#  '0_vars_corr_0HC_n25000.csv : LogisticRegression',
#  '0_vars_corr_0HC_n25000.csv : DecisionTree',
#  '0_vars_corr_0HC_n25000.csv : XGBoost',
#  '0_vars_corr_0HC_n25000.csv : MultinomialNB',
#  '0_vars_corr_0HC_n25000.csv : GaussianNB',
#  '0_vars_corr_0HC_n100.csv : PassiveAgressive',
#  '0_vars_corr_0HC_n100.csv : SGDClassifier',
#  '0_vars_corr_0HC_n100.csv : RandomForest',
#  '0_vars_corr_0HC_n100.csv : Perceptron',
#  '0_vars_corr_0HC_n100.csv : RidgeClassifier',
#  '0_vars_corr_0HC_n100.csv : LogisticRegression',
#  '0_vars_corr_0HC_n100.csv : DecisionTree',
#  '0_vars_corr_0HC_n100.csv : XGBoost',
#  '0_vars_corr_0HC_n100.csv : MultinomialNB',
#  '0_vars_corr_0HC_n100.csv : GaussianNB',
#  '0_vars_corr_0HC_n10000_skew_0.7354.csv : PassiveAgressive',
#  '0_vars_corr_0HC_n10000_skew_0.7354.csv : SGDClassifier',
#  '0_vars_corr_0HC_n10000_skew_0.7354.csv : RandomForest',
#  '0_vars_corr_0HC_n10000_skew_0.7354.csv : Perceptron',
#  '0_vars_corr_0HC_n10000_skew_0.7354.csv : RidgeClassifier',
#  '0_vars_corr_0HC_n10000_skew_0.7354.csv : LogisticRegression',
#  '0_vars_corr_0HC_n10000_skew_0.7354.csv : DecisionTree',
#  '0_vars_corr_0HC_n10000_skew_0.7354.csv : XGBoost',
#  '0_vars_corr_0HC_n10000_skew_0.7354.csv : MultinomialNB',
#  '0_vars_corr_0HC_n10000_skew_0.7354.csv : GaussianNB',
#  '3_vars_corr_1HC_n10000.csv : PassiveAgressive',
#  '3_vars_corr_1HC_n10000.csv : SGDClassifier',
#  '3_vars_corr_1HC_n10000.csv : RandomForest',
#  '3_vars_corr_1HC_n10000.csv : Perceptron',
#  '3_vars_corr_1HC_n10000.csv : RidgeClassifier',
#  '3_vars_corr_1HC_n10000.csv : LogisticRegression',
#  '3_vars_corr_1HC_n10000.csv : DecisionTree',
#  '3_vars_corr_1HC_n10000.csv : XGBoost',
#  '3_vars_corr_1HC_n10000.csv : MultinomialNB',
#  '3_vars_corr_1HC_n10000.csv : GaussianNB',
#  '0_vars_corr_0HC_n10000_skew_0.8612.csv : PassiveAgressive',
#  '0_vars_corr_0HC_n10000_skew_0.8612.csv : SGDClassifier',
#  '0_vars_corr_0HC_n10000_skew_0.8612.csv : RandomForest',
#  '0_vars_corr_0HC_n10000_skew_0.8612.csv : Perceptron',
#  '0_vars_corr_0HC_n10000_skew_0.8612.csv : RidgeClassifier',
#  '0_vars_corr_0HC_n10000_skew_0.8612.csv : LogisticRegression',
#  '0_vars_corr_0HC_n10000_skew_0.8612.csv : DecisionTree',
#  '0_vars_corr_0HC_n10000_skew_0.8612.csv : XGBoost',
#  '0_vars_corr_0HC_n10000_skew_0.8612.csv : MultinomialNB',
#  '0_vars_corr_0HC_n10000_skew_0.8612.csv : GaussianNB',
#  '0_vars_corr_0HC_n15000.csv : PassiveAgressive',
#  '0_vars_corr_0HC_n15000.csv : SGDClassifier',
#  '0_vars_corr_0HC_n15000.csv : RandomForest',
#  '0_vars_corr_0HC_n15000.csv : Perceptron',
#  '0_vars_corr_0HC_n15000.csv : RidgeClassifier',
#  '0_vars_corr_0HC_n15000.csv : LogisticRegression',
#  '0_vars_corr_0HC_n15000.csv : DecisionTree',
#  '0_vars_corr_0HC_n15000.csv : XGBoost',
#  '0_vars_corr_0HC_n15000.csv : MultinomialNB',
#  '0_vars_corr_0HC_n15000.csv : GaussianNB',
#  '2_vars_corr_1HC_n10000.csv : PassiveAgressive',
#  '2_vars_corr_1HC_n10000.csv : SGDClassifier',
#  '2_vars_corr_1HC_n10000.csv : RandomForest',
#  '2_vars_corr_1HC_n10000.csv : Perceptron',
#  '2_vars_corr_1HC_n10000.csv : RidgeClassifier',
#  '2_vars_corr_1HC_n10000.csv : LogisticRegression',
#  '2_vars_corr_1HC_n10000.csv : DecisionTree',
#  '2_vars_corr_1HC_n10000.csv : XGBoost',
#  '2_vars_corr_1HC_n10000.csv : MultinomialNB',
#  '2_vars_corr_1HC_n10000.csv : GaussianNB',
#  '0_vars_corr_0HC_n10000_skew_0.9694.csv : PassiveAgressive',
#  '0_vars_corr_0HC_n10000_skew_0.9694.csv : SGDClassifier',
#  '0_vars_corr_0HC_n10000_skew_0.9694.csv : RandomForest',
#  '0_vars_corr_0HC_n10000_skew_0.9694.csv : Perceptron',
#  '0_vars_corr_0HC_n10000_skew_0.9694.csv : RidgeClassifier',
#  '0_vars_corr_0HC_n10000_skew_0.9694.csv : LogisticRegression',
#  '0_vars_corr_0HC_n10000_skew_0.9694.csv : DecisionTree',
#  '0_vars_corr_0HC_n10000_skew_0.9694.csv : XGBoost',
#  '0_vars_corr_0HC_n10000_skew_0.9694.csv : MultinomialNB',
#  '0_vars_corr_0HC_n10000_skew_0.9694.csv : GaussianNB',
#  '2_vars_corr_2HC_n10000.csv : PassiveAgressive',
#  '2_vars_corr_2HC_n10000.csv : SGDClassifier',
#  '2_vars_corr_2HC_n10000.csv : RandomForest',
#  '2_vars_corr_2HC_n10000.csv : Perceptron',
#  '2_vars_corr_2HC_n10000.csv : RidgeClassifier',
#  '2_vars_corr_2HC_n10000.csv : LogisticRegression',
#  '2_vars_corr_2HC_n10000.csv : DecisionTree',
#  '2_vars_corr_2HC_n10000.csv : XGBoost',
#  '2_vars_corr_2HC_n10000.csv : MultinomialNB',
#  '2_vars_corr_2HC_n10000.csv : GaussianNB',
#  '0_vars_corr_0HC_n10000.csv : PassiveAgressive',
#  '0_vars_corr_0HC_n10000.csv : SGDClassifier',
#  '0_vars_corr_0HC_n10000.csv : RandomForest',
#  '0_vars_corr_0HC_n10000.csv : Perceptron',
#  '0_vars_corr_0HC_n10000.csv : RidgeClassifier',
#  '0_vars_corr_0HC_n10000.csv : LogisticRegression',
#  '0_vars_corr_0HC_n10000.csv : DecisionTree',
#  '0_vars_corr_0HC_n10000.csv : XGBoost',
#  '0_vars_corr_0HC_n10000.csv : MultinomialNB',
#  '0_vars_corr_0HC_n10000.csv : GaussianNB',
#  '0_vars_corr_0HC_n5000.csv : PassiveAgressive',
#  '0_vars_corr_0HC_n5000.csv : SGDClassifier',
#  '0_vars_corr_0HC_n5000.csv : RandomForest',
#  '0_vars_corr_0HC_n5000.csv : Perceptron',
#  '0_vars_corr_0HC_n5000.csv : RidgeClassifier',
#  '0_vars_corr_0HC_n5000.csv : LogisticRegression',
#  '0_vars_corr_0HC_n5000.csv : DecisionTree',
#  '0_vars_corr_0HC_n5000.csv : XGBoost',
#  '0_vars_corr_0HC_n5000.csv : MultinomialNB',
#  '0_vars_corr_0HC_n5000.csv : GaussianNB',
#  '0_vars_corr_0HC_n10000_skew_0.508.csv : PassiveAgressive',
#  '0_vars_corr_0HC_n10000_skew_0.508.csv : SGDClassifier',
#  '0_vars_corr_0HC_n10000_skew_0.508.csv : RandomForest',
#  '0_vars_corr_0HC_n10000_skew_0.508.csv : Perceptron',
#  '0_vars_corr_0HC_n10000_skew_0.508.csv : RidgeClassifier',
#  '0_vars_corr_0HC_n10000_skew_0.508.csv : LogisticRegression',
#  '0_vars_corr_0HC_n10000_skew_0.508.csv : DecisionTree',
#  '0_vars_corr_0HC_n10000_skew_0.508.csv : XGBoost',
#  '0_vars_corr_0HC_n10000_skew_0.508.csv : MultinomialNB',
#  '0_vars_corr_0HC_n10000_skew_0.508.csv : GaussianNB',
#  '0_vars_corr_0HC_n10000_skew_0.6222.csv : PassiveAgressive',
#  '0_vars_corr_0HC_n10000_skew_0.6222.csv : SGDClassifier',
#  '0_vars_corr_0HC_n10000_skew_0.6222.csv : RandomForest',
#  '0_vars_corr_0HC_n10000_skew_0.6222.csv : Perceptron',
#  '0_vars_corr_0HC_n10000_skew_0.6222.csv : RidgeClassifier',
#  '0_vars_corr_0HC_n10000_skew_0.6222.csv : LogisticRegression',
#  '0_vars_corr_0HC_n10000_skew_0.6222.csv : DecisionTree',
#  '0_vars_corr_0HC_n10000_skew_0.6222.csv : XGBoost',
#  '0_vars_corr_0HC_n10000_skew_0.6222.csv : MultinomialNB',
#  '0_vars_corr_0HC_n10000_skew_0.6222.csv : GaussianNB',
#  '3_vars_corr_2HC_n10000B.csv : PassiveAgressive',
#  '3_vars_corr_2HC_n10000B.csv : SGDClassifier',
#  '3_vars_corr_2HC_n10000B.csv : RandomForest',
#  '3_vars_corr_2HC_n10000B.csv : Perceptron',
#  '3_vars_corr_2HC_n10000B.csv : RidgeClassifier',
#  '3_vars_corr_2HC_n10000B.csv : LogisticRegression',
#  '3_vars_corr_2HC_n10000B.csv : DecisionTree',
#  '3_vars_corr_2HC_n10000B.csv : XGBoost',
#  '3_vars_corr_2HC_n10000B.csv : MultinomialNB',
#  '3_vars_corr_2HC_n10000B.csv : GaussianNB',
#  '0_vars_corr_0HC_n1000.csv : PassiveAgressive',
#  '0_vars_corr_0HC_n1000.csv : SGDClassifier',
#  '0_vars_corr_0HC_n1000.csv : RandomForest',
#  '0_vars_corr_0HC_n1000.csv : Perceptron',
#  '0_vars_corr_0HC_n1000.csv : RidgeClassifier',
#  '0_vars_corr_0HC_n1000.csv : LogisticRegression',
#  '0_vars_corr_0HC_n1000.csv : DecisionTree',
#  '0_vars_corr_0HC_n1000.csv : XGBoost',
#  '0_vars_corr_0HC_n1000.csv : MultinomialNB',
#  '0_vars_corr_0HC_n1000.csv : GaussianNB',
#  '3_vars_corr_2HC_n10000.csv : PassiveAgressive',
#  '3_vars_corr_2HC_n10000.csv : SGDClassifier',
#  '3_vars_corr_2HC_n10000.csv : RandomForest',
#  '3_vars_corr_2HC_n10000.csv : Perceptron',
#  '3_vars_corr_2HC_n10000.csv : RidgeClassifier',
#  '3_vars_corr_2HC_n10000.csv : LogisticRegression',
#  '3_vars_corr_2HC_n10000.csv : DecisionTree',
#  '3_vars_corr_2HC_n10000.csv : XGBoost',
#  '3_vars_corr_2HC_n10000.csv : MultinomialNB',
#  '3_vars_corr_2HC_n10000.csv : GaussianNB',
#  '0_vars_corr_0HC_n20000.csv : PassiveAgressive',
#  '0_vars_corr_0HC_n20000.csv : SGDClassifier',
#  '0_vars_corr_0HC_n20000.csv : RandomForest',
#  '0_vars_corr_0HC_n20000.csv : Perceptron',
#  '0_vars_corr_0HC_n20000.csv : RidgeClassifier',
#  '0_vars_corr_0HC_n20000.csv : LogisticRegression',
#  '0_vars_corr_0HC_n20000.csv : DecisionTree',
#  '0_vars_corr_0HC_n20000.csv : XGBoost',
#  '0_vars_corr_0HC_n20000.csv : MultinomialNB',
#  '0_vars_corr_0HC_n20000.csv : GaussianNB']
